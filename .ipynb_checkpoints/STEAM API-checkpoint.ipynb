# %%
import math
import sys
import requests
import json
import apikey
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
apikey = apikey.apikey
steamUserID = input()
if steamUserID == '':
    steamUserID = '76561197963833067' #me
    #steamUserID = '76561197960297139' #qualor

# %%
#look at all my friends (by id)
r1 = requests.get(f'http://api.steampowered.com/ISteamUser/GetFriendList/v0001/?key={apikey}&steamid={steamUserID}&relationship=friend')
friends = r1.json()

# %%
ii = 0
px = []
py = []
for z in friends['friendslist']['friends']:
    thisID = z['steamid']
    
    r3 = requests.get(f'https://api.steampowered.com/ISteamUser/GetPlayerSummaries/v2/?key={apikey}&format=json&steamids={thisID}')
    data3 = r3.json()
    print(data3['response']['players'][0]['personaname'])
    user = data3['response']['players'][0]['personaname']
    
    r2 = requests.get(f'http://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/?key={apikey}&steamid={thisID}&format=json&include_appinfo=1')
    #print(f'http://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/?key={apikey}&steamid={thisID}&format=json&include_appinfo=1')
    data2 = r2.json()
    
    with open(f"{user}.txt", "w") as f:
        f.write(json.dumps(data2))
    time.sleep(1)
    f.close()
    
    #print(data2)
    y = {}
    try:
        for x in data2['response']['games']:
            y[x['name']] = x['playtime_forever']
            #print(f"{x['name']} :: {x['playtime_forever']}")
            dat = pd.DataFrame(data2['response']['games'])

        gameplay = dat[['name','playtime_forever']]
        gameplay.columns = ['Game','Play Hours']
        gameplay1 = pd.DataFrame(gameplay)
        print(gameplay1.mean()['Play Hours'])
        playtime = gameplay1.mean()['Play Hours']

        px.append(user)
        py.append(playtime)
    except:
        print(' ---no public?')

    if (ii > 200):
        print("done")
        break 
    ii = ii +1

    
playtimes = pd.DataFrame(px, py)
# Out:
# Salvag3
# 4097.188405797101
# ShagNasty
# 624.4979919678715
# Vargoth
# 1852.873417721519
# Tripse7enZ
# 397.7894736842105
# slackme
#  ---no public?
# luke
# 424.9744525547445
# Soldnor
# 1020.9202898550725
# Atavistic
# 4204.673913043478
# J0nny5 Alive
# 291.7931034482759
# Oiiioi
# 416.4391785150079
# mjxii
# 3465.65
# prancetron
# 2142.511111111111
# haliphax
# 136.8507462686567
# Fluffy Bunny [JRG]
# 3128.391304347826
# umyslut
# 58.206896551724135
# Notorious
# 2504.777777777778
# BaronVonSnoopy
# 2549.4201680672268
# rocketrobot
# 4421.609090909091
# Shinan
# 338.26926648096565
# The Crab Nicholson
# 435.1320754716981
# Akc0307
# 112.0
# [FST] Antilar
# 8783.468354430379
# 009
# 279.61
# Phailen
# 1373.9705882352941
# ToastedRav
# 3988.06
# Dubulese
# 1593.013888888889
# ^1Death ^9From ^4Above
# 6428.5
# tooserious
# 1981.6
# wolviranger
# 301.4795321637427
# Iron Thorin
# 3896.875
# Dirge
# 4977.951807228916
# [D w 🐇]  David S Pumpkins
# 1031.659574468085
# phyziks42
# 2570.0
# chaserchap
# 574.3088235294117
# Vastrallakas
# 2006.9033816425122
# Tonail
# 749.2173913043479
# Yobgal
# 1005.7105263157895
# Silvanus
# 931.8571428571429
# lostclause
# 357.8021015761821
# Isenki
# 1411.3157894736842
# Cmdr. Shepard
# 798.8609625668449
# clb3820
# 1518.0718954248366
# prancetron
# 3165.8947368421054
# moshesa2
#  ---no public?
# §§SCUM OF THE EARTH
# 15824.42857142857
# Tubsterdoodle
# 156.575
# Merigold
# 3651.909090909091
# phyziks42
# 1278.6190476190477
# tikibelly
# 765.64
# Cyclonic
# 182.68085106382978
# Redd
# 707.7714808043876
# Billyrage
# 2372.244094488189
# kbat029
# 2853.909090909091
# Jello616
# 648.0
# StarKnight549
# 2744.846153846154
# violinplayer86
# 21388.190476190477
# evilsonic31
# 700.2206896551725
# Freakin' Shweet LiquidCups
# 285.6683417085427
# jimwt9
#  ---no public?
# queernose
# 307.0
# PootyPants
# 296.2857142857143

# %%
playtimes = playtimes.reset_index()
playtimes.columns = ['time', 'user']
playtimes = pd.DataFrame(playtimes[['user','time']])
playtimes = playtimes.round(0)
playtimes.sort_values(by='time', ascending=False)
# Out:
#                           user     time
# 53              violinplayer86  21388.0
# 42         §§SCUM OF THE EARTH  15824.0
# 20               [FST] Antilar   8783.0
# 25      ^1Death ^9From ^4Above   6428.0
# 29                       Dirge   4978.0
# 16                 rocketrobot   4422.0
# 6                    Atavistic   4205.0
# 0                      Salvag3   4097.0
# 23                  ToastedRav   3988.0
# 28                 Iron Thorin   3897.0
# 44                    Merigold   3652.0
# 9                        mjxii   3466.0
# 41                  prancetron   3166.0
# 12          Fluffy Bunny [JRG]   3128.0
# 50                     kbat029   2854.0
# 52               StarKnight549   2745.0
# 31                   phyziks42   2570.0
# 15              BaronVonSnoopy   2549.0
# 14                   Notorious   2505.0
# 49                   Billyrage   2372.0
# 10                  prancetron   2143.0
# 33                Vastrallakas   2007.0
# 26                  tooserious   1982.0
# 2                      Vargoth   1853.0
# 24                    Dubulese   1593.0
# 40                     clb3820   1518.0
# 38                      Isenki   1411.0
# 22                     Phailen   1374.0
# 45                   phyziks42   1279.0
# 30   [D w 🐇]  David S Pumpkins   1032.0
# 5                      Soldnor   1021.0
# 35                      Yobgal   1006.0
# 36                    Silvanus    932.0
# 39               Cmdr. Shepard    799.0
# 46                   tikibelly    766.0
# 34                      Tonail    749.0
# 48                        Redd    708.0
# 54                 evilsonic31    700.0
# 51                    Jello616    648.0
# 1                    ShagNasty    624.0
# 32                  chaserchap    574.0
# 18          The Crab Nicholson    435.0
# 4                         luke    425.0
# 8                       Oiiioi    416.0
# 3                   Tripse7enZ    398.0
# 37                  lostclause    358.0
# 17                      Shinan    338.0
# 56                   queernose    307.0
# 27                 wolviranger    301.0
# 57                  PootyPants    296.0
# 7                 J0nny5 Alive    292.0
# 55  Freakin' Shweet LiquidCups    286.0
# 21                         009    280.0
# 47                    Cyclonic    183.0
# 43               Tubsterdoodle    157.0
# 11                    haliphax    137.0
# 19                     Akc0307    112.0
# 13                     umyslut     58.0

# %%
playtimes = playtimes[['time', 'user']].sort_values(by='time', ascending=False)
playtimes =  playtimes.reset_index()
playtimes.drop('index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-b359ce65c0f5> in <module>()
#       2 playtimes = playtimes[['time', 'user']].sort_values(by='time', ascending=False)
#       3 playtimes =  playtimes.reset_index()
# ----> 4 playtimes.drop('index')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
playtimes
# Out:
#     index     time                        user
# 0       0  21388.0              violinplayer86
# 1       1  15824.0         §§SCUM OF THE EARTH
# 2       2   8783.0               [FST] Antilar
# 3       3   6428.0      ^1Death ^9From ^4Above
# 4       4   4978.0                       Dirge
# 5       5   4422.0                 rocketrobot
# 6       6   4205.0                   Atavistic
# 7       7   4097.0                     Salvag3
# 8       8   3988.0                  ToastedRav
# 9       9   3897.0                 Iron Thorin
# 10     10   3652.0                    Merigold
# 11     11   3466.0                       mjxii
# 12     12   3166.0                  prancetron
# 13     13   3128.0          Fluffy Bunny [JRG]
# 14     14   2854.0                     kbat029
# 15     15   2745.0               StarKnight549
# 16     16   2570.0                   phyziks42
# 17     17   2549.0              BaronVonSnoopy
# 18     18   2505.0                   Notorious
# 19     19   2372.0                   Billyrage
# 20     20   2143.0                  prancetron
# 21     21   2007.0                Vastrallakas
# 22     22   1982.0                  tooserious
# 23     23   1853.0                     Vargoth
# 24     24   1593.0                    Dubulese
# 25     25   1518.0                     clb3820
# 26     26   1411.0                      Isenki
# 27     27   1374.0                     Phailen
# 28     28   1279.0                   phyziks42
# 29     29   1032.0   [D w 🐇]  David S Pumpkins
# 30     30   1021.0                     Soldnor
# 31     31   1006.0                      Yobgal
# 32     32    932.0                    Silvanus
# 33     33    799.0               Cmdr. Shepard
# 34     34    766.0                   tikibelly
# 35     35    749.0                      Tonail
# 36     36    708.0                        Redd
# 37     37    700.0                 evilsonic31
# 38     38    648.0                    Jello616
# 39     39    624.0                   ShagNasty
# 40     40    574.0                  chaserchap
# 41     41    435.0          The Crab Nicholson
# 42     42    425.0                        luke
# 43     43    416.0                      Oiiioi
# 44     44    398.0                  Tripse7enZ
# 45     45    358.0                  lostclause
# 46     46    338.0                      Shinan
# 47     47    307.0                   queernose
# 48     48    301.0                 wolviranger
# 49     49    296.0                  PootyPants
# 50     50    292.0                J0nny5 Alive
# 51     51    286.0  Freakin' Shweet LiquidCups
# 52     52    280.0                         009
# 53     53    183.0                    Cyclonic
# 54     54    157.0               Tubsterdoodle
# 55     55    137.0                    haliphax
# 56     56    112.0                     Akc0307
# 57     57     58.0                     umyslut

# %%
# Out:
# (4097.188405797101+0j)

# %%
gameplay.sort_values('Play Hours', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-666f2bb9318e> in <module>()
# ----> 1 gameplay.sort_values('Play Hours', ascending=False)
#
# NameError: name 'gameplay' is not defined
